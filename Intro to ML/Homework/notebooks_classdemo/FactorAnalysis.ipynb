# %% [markdown]
# ### Factor Analysis
# This notebook illustrates Factor Analysis model and how to use sklearn.FactorAnalysis method to conduct factor analysis on a sample data set.

# %%
import numpy as np
import csv
from scipy.stats import norm
import pandas as pd
from sklearn.decomposition import FactorAnalysis
import matplotlib.pyplot as plt
import scipy.stats.mstats as ms
import mpld3
from mpld3 import plugins
# %matplotlib inline

# %%
# set the factor analysis model parameters
mu0 = 0
sigma0 = 1
W = np.array([8,1])
# W = W[:,np.newaxis]
mu = np.array([0,0])
# mu = mu[:,np.newaxis]
Psi = np.array([[1,0],[0,1]])

n = 1000
# sample z's from the distribution 
Z = norm(mu0, sigma0).rvs(n)
# Z = Z[:,np.newaxis]
# generate x from z
X = []
for z in Z:
    mu1 = z*W + mu
    x = np.random.multivariate_normal(mu1.flatten(),Psi,1).flatten()
    X.append(x)
X = np.array(X)

# plot them side by side
fig, axs = plt.subplots(1, 4)
fig.set_size_inches([12,6])

P = np.zeros([4,n])
P[0] = Z.flatten()
P[2] = X[:,0]
P[3] = X[:,1]
x = np.linspace(-5,5,100)
axs[0].plot(x, 1/(sigma0 * np.sqrt(2 * np.pi)) * np.exp( - (x - mu0)**2 / (2 * sigma0**2) ), linewidth=2, color='r')
if n > 10:
    axs[0].hist(Z,alpha=0.3,bins=20,color='b')
    #axs[0].hist(Z,alpha=0.3,bins=20,color='b',normed=True)

points = axs[0].scatter(P[0],P[1])
points = axs[1].scatter(P[2],P[3])
points = axs[2].scatter(P[0],P[2])
points = axs[3].scatter(P[0],P[3])
axs[0].set_ylim([-0.1,1])
if n > 1:
    axs[1].set_xlim([np.min(X),np.max(X)])
    axs[1].set_ylim([np.min(X),np.max(X)])
axs[0].legend(['true pdf','samples','empirical distribution'])
plugins.connect(fig, plugins.LinkedBrush(points))
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el3098447796425447423047596"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el3098447796425447423047596", {"width": 864.0, "height": 432.0, "axes": [{"bbox": [0.125, 0.125, 0.16847826086956524, 0.755], "xlim": [-5.5, 5.5], "ylim": [-0.1, 1.0], "xdomain": [-5.5, 5.5], "ydomain": [-0.1, 1.0], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 5, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el309844781486192", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el309844782129104", "color": "#FF0000", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data20", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el309844782411488", "color": "#FF0000", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 1000002.0, "drawstyle": "default"}], "paths": [{"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el309844782191904", "dasharray": "none", "alpha": 0.3, "facecolor": "rgba(0, 0, 255, 0.3)", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el309844782191424", "dasharray": "none", "alpha": 0.3, "facecolor": "rgba(0, 0, 255, 0.3)", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data04", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el309844782193152", "dasharray": "none", "alpha": 0.3, "facecolor": "rgba(0, 0, 255, 0.3)", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data05", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el309844782193872", "dasharray": "none", "alpha": 0.3, "facecolor": "rgba(0, 0, 255, 0.3)", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data06", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el309844782194592", "dasharray": "none", "alpha": 0.3, "facecolor": "rgba(0, 0, 255, 0.3)", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data07", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el309844782228144", "dasharray": "none", "alpha": 0.3, "facecolor": "rgba(0, 0, 255, 0.3)", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data08", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el309844782228864", "dasharray": "none", "alpha": 0.3, "facecolor": "rgba(0, 0, 255, 0.3)", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data09", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el309844782229584", "dasharray": "none", "alpha": 0.3, "facecolor": "rgba(0, 0, 255, 0.3)", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data10", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el309844782230304", "dasharray": "none", "alpha": 0.3, "facecolor": "rgba(0, 0, 255, 0.3)", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data11", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el309844782231024", "dasharray": "none", "alpha": 0.3, "facecolor": "rgba(0, 0, 255, 0.3)", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data12", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el309844782289152", "dasharray": "none", "alpha": 0.3, "facecolor": "rgba(0, 0, 255, 0.3)", "ed ...

# %%
print(X.shape)
# Out:
# (1000, 2)

# %% [markdown]
# ### Analyzing data using Factor Analysis model

# %%
# Load data
X = np.zeros((387,11))
names = []
with open('data/04cars.dat','r') as f:
    reader = csv.reader(f)
    l1 = next(reader)
    lind = 0
    for row in reader:
        names.append(row[0])
        X[lind,:] = row[8:]
        lind = lind + 1
        
# variable names
l = l1[8:]

# %%
print(l)
# Out:
# ['Retail Price', 'Dealer Price', 'Engine Size', 'Cylinders', 'Horsepower', 'City MPG', 'Highway MPG', 'Weight', 'Wheel Base', 'Length', 'Width']

# %%
# Setup the factor analysis model
fa = FactorAnalysis(n_components=2)
# fit the data
zX = ms.zscore(X)
f = fa.fit(zX)
W = ms.zscore(np.transpose(f.components_))
Psi = f.noise_variance_

# %%
# We first visualize and interpret the W matrix
# Project unit vectors corresponding to each feature dimension to the 2 dimension space
fig = plt.figure(figsize=[10,8])
for i in range(W.shape[0]):
    plt.plot([0,W[i,0]],[0,W[i,1]])
    plt.text(W[i,0],W[i,1],l[i])
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el3098444124025605071274248"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el3098444124025605071274248", {"width": 720.0, "height": 576.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [-1.9497683072944256, 1.3841985061966675], "ylim": [-1.049102074179109, 1.9320179259060324], "xdomain": [-1.9497683072944256, 1.3841985061966675], "ydomain": [-1.049102074179109, 1.9320179259060324], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el309844756591520", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el309844774371536", "color": "#1F77B4", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el309844774372928", "color": "#FF7F0E", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el309844774374320", "color": "#2CA02C", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data04", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el309844774412640", "color": "#D62728", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data05", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el309844774414032", "color": "#9467BD", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data06", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el309844774415424", "color": "#8C564B", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data07", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el309844774470176", "color": "#E377C2", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data08", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el309844774471568", "color": "#7F7F7F", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data09", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el309844774472960", "color": "#BCBD22", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data10", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el309844774519472", "color": "#17BECF", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data11", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el309844756621344", "color": "#1F77B4", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}], "paths": [], "markers": [], "texts": [{"text": "Retail Price", "position": [1.2326545601288905, 0.6041525721588286], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el309844774372160"}, {"text": "Dealer Price", "position": [1.232532366344348, 0.6150689875171683], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el309844774373552"}, {"text": "Engine Size", "position": [0.41919391163305525, -0.728083788205182], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el309844774374944"}, {"text": "Cylinders", "position": [0.5324055770329845, -0.516998625924869], "coordinates" ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://d3js.org/d3.v5"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.5.1.js", function(){
#
#          mpld3.draw_figure("fig_el3098444124025605071274248", {"width": 720.0, "height": 576.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [-1.9497683072944256, 1.3841985061966675], "ylim": [-1.049102074179109, 1.9320179259060324], "xdomain":

# %%
# Find latent scores for each data point using the latent factors
Z = f.fit_transform(zX)
fig = plt.figure(figsize=[12,10])
#for i in range(W.shape[0]):
#    plt.plot([0,W[i,0]],[0,W[i,1]])

scatter = plt.scatter(Z[:,0],Z[:,1])
#for i in range(Z.shape[0]):
    #if abs(Z[i,0]) > 1.5 or abs(Z[i,1]) > 1.5:
    #plt.text(Z[i,0],Z[i,1],names[i],fontsize=8)
    
labels1 = ['%s'%(names[i]) for i in range(Z.shape[0])]
tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=labels1)
mpld3.plugins.connect(fig, tooltip)
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el3098447744157129624055989"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el3098447744157129624055989", {"width": 864.0, "height": 720.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [-1.6230899945285977, 8.473157228518081], "ylim": [-3.505027124652317, 5.494900668153582], "xdomain": [-1.6230899945285977, 8.473157228518081], "ydomain": [-3.505027124652317, 5.494900668153582], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 11, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el309844756558992", "lines": [], "paths": [], "markers": [], "texts": [], "collections": [{"offsets": "data01", "xindex": 0, "yindex": 1, "paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "pathtransforms": [[6.0, 0.0, 0.0, 6.0, 0.0, 0.0]], "alphas": [null], "edgecolors": ["#1F77B4"], "facecolors": ["#1F77B4"], "edgewidths": [1.0], "offsetcoordinates": "data", "pathcoordinates": "display", "zorder": 1, "id": "el309844776700848"}], "images": [], "sharex": [], "sharey": []}], "data": {"data01": [[-1.0983268266994046, 1.2721586336120985], [-1.0527226783190677, 1.4187122232383793], [-0.9452642171749048, 0.7024636785013103], [-0.9350541064573351, 0.7356851047181326], [-0.8542719169626484, 0.7629855008121486], [-0.9938687652501905, 0.9332129963489146], [-0.9247473879260082, 0.9611379835805886], [-1.0137606869084412, 0.8920542526410238], [-0.9912934617615777, 1.0054572467748906], [-0.9024238477859898, 0.968103799846333], [-0.8961499883111561, 0.9390278470651295], [-1.024253905953351, 1.1840557380677548], [-0.979477532447165, 1.3523623283895219], [-0.893228540707256, 1.189448343197203], [-1.1517426319868849, 1.321435847935569], [-1.090605512579464, 1.3462920346818057], [-1.0854037128647778, 1.3305868070142481], [-0.990385399335264, 0.7744917362892111], [-0.91156234640886, 0.8266773962674647], [-0.9114472641116651, 0.8021199665301693], [-0.8722691830495749, 0.06640664800693959], [-1.164169666208294, 1.2199755050358962], [-1.1187003475202182, 1.1949806586648914], [-1.0603002730042772, 0.7609214311801048], [-0.9961232333150791, 0.7944382502476104], [-0.9428684759688021, 0.8253329490377282], [-0.8394121922580666, 1.5640052304669723], [-1.0360073599092825, 1.0210392544004463], [-0.9422020154129058, 1.0534719085383368], [-0.9032265907910655, 0.625291505199567], [-1.1304825179526163, 0.6190395205064906], [-0.9615118652134451, 0.731253983048445], [-0.883556156730431, 0.783020619163393], [-0.9331507739978254, 0.6775126564384012], [-0.8564664050781403, 0.7284375883601517], [-1.029182709960392, 1.627342728817991], [-1.0158273800971387, 0.726859694162466], [-0.9306508855937555, 0.7844031776847873], [-1.0491979223886407, 0.6876554641852834], [-0.8749165265766582, 0.7326115357272576], [-0.9784986121657874, 1.1688467259471904], [-0.938061536677137, 1.184073515010855], [-0.9247146157442293, 1.1928603217531848], [-1.147311134294201, 1.830895421891789], [-1.1055208047631602, 1.7 ...
